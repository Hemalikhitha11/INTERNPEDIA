# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemalikhitha11/INTERNPEDIA/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
for dirname, _, filenames in os.walk('/tested (1).csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df=sns.load_dataset("titanic")

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Display the number of rows and columns in the dataframe
print("Number of rows:", df.shape[0])
print("Number of columns:", df.shape[1])

# Display summary statistics for numeric columns
print(df.describe())

# Check the data types of columns
print(df.dtypes)
# Out:
# Number of rows: 891
# Number of columns: 15
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200
# survived          int64
# pclass            int64
# sex              object
# age             float64
# sibsp             int64
# parch             int64
# fare            float64
# embarked         object
# class          category
# ...

# %%
X=df2.drop("survived",axis=1)
y=df2["survived"]

print("shape of X:", X.shape)
print("shape of y:", y.shape),
# Out:
# shape of X: (891, 4)
# shape of y: (891,)
# (None,)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,y_train,X_test,y_test=train_test_split(X,y,test_size=0.3)
print("shape of X_train:", X_train.shape)
print("shape of X_test", X_test.shape)
print("shape of y_train", y_train.shape)
print("shape of y_test",  y_test.shape)
# Out:
# shape of X_train: (623, 4)
# shape of X_test (623,)
# shape of y_train (268, 4)
# shape of y_test (268,)

# %%
survival_by_sex = df.groupby('sex')['survived'].mean()
survival_by_sex.plot(kind='bar', color=['blue', 'pink'])
plt.xlabel('Sex')
plt.ylabel('Survival Rate')
plt.title('Survival Rate by Sex')
plt.show()

# %%
overall_survival_rate = df['survived'].mean()
print("Overall Survival Rate:", overall_survival_rate)
# Out:
# Overall Survival Rate: 0.3838383838383838
